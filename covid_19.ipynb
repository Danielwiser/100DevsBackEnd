# %% [markdown]
# <a href="https://colab.research.google.com/github/danielbuernor/100devsbackend/blob/main/covid_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
covid_19 = pd.read_csv('/content/covid_19.csv')

# %%
print(covid_19.head())
print(covid_19.tail())
print(covid_19.describe())
print(covid_19.info())
print(covid_19.columns)
print(covid_19.index)
# Out:
#    country country_code continent  population indicator  weekly_count  \
# 0  Austria          AUT    Europe     8978929     cases           NaN
# 1  Austria          AUT    Europe     8978929     cases           NaN
# 2  Austria          AUT    Europe     8978929     cases           NaN
# 3  Austria          AUT    Europe     8978929     cases           NaN
# 4  Austria          AUT    Europe     8978929     cases           NaN
#
#   year_week  rate_14_day  cumulative_count          source  note
# 0   2020-01          NaN               NaN  TESSy COVID-19   NaN
# 1   2020-02          NaN               NaN  TESSy COVID-19   NaN
# 2   2020-03          NaN               NaN  TESSy COVID-19   NaN
# 3   2020-04          NaN               NaN  TESSy COVID-19   NaN
# 4   2020-05          NaN               NaN  TESSy COVID-19   NaN
#       country country_code continent  population indicator  weekly_count  \
# 12209  Sweden          SWE    Europe    10452326    deaths          28.0
# ...

# %%
## inspecting dataframe
## removing missing values
print(covid_19)
covid_19['country_code'].fillna(0)
covid_19.isna().sum()
covid_19.isna().any()
## replacing numerical columns with missing values with the mean of respective columns and object data types with 'none'
replace_na = {'country_code': 'none', 'weekly_count': 32979.56, 'rate_14_day': 249.35407, 'cumulative_count' : 2863095, 'note': 'none'}
covid_19.fillna(replace_na, inplace=True)
covid_19.head()
covid_19.tail()
# Out:
#        country country_code continent  population indicator  weekly_count  \
# 0      Austria          AUT    Europe     8978929     cases      32979.56
# 1      Austria          AUT    Europe     8978929     cases      32979.56
# 2      Austria          AUT    Europe     8978929     cases      32979.56
# 3      Austria          AUT    Europe     8978929     cases      32979.56
# 4      Austria          AUT    Europe     8978929     cases      32979.56
# ...        ...          ...       ...         ...       ...           ...
# 12209   Sweden          SWE    Europe    10452326    deaths         28.00
# 12210   Sweden          SWE    Europe    10452326    deaths         41.00
# 12211   Sweden          SWE    Europe    10452326    deaths         25.00
# 12212   Sweden          SWE    Europe    10452326    deaths         33.00
# 12213   Sweden          SWE    Europe    10452326    deaths          0.00
#
#       year_week  rate_14_day  cumulative_count          source  note
# ...
